# %%
import pickle 
import numpy as np
file = open("../models/Reacher_unity_v22019_05_31_22_09_36_replay_buffer_", "rb")
replay_buffer = pickle.load(file)

# %%
states = []
for replay_ in replay_buffer:
    states.append(replay_["state"])
states = np.array(states)

# %%
states_min = np.min(states, axis=0)
states_max = np.max(states, axis=0)

# %%
import pandas as pd
states_minmax_df = pd.DataFrame.from_dict({"states": np.arange(len(states_min)), 
                                           "min": states_min, 
                                           "max": states_max})
states_minmax_df
# Out:
#     states       min       max
# 0        0  0.068805  0.918232
# 1        1 -0.002396  1.006595
# 2        2  0.055851  0.939477
# 3        3  0.000035  1.000000
# 4        4  0.322688  0.705241
# 5        5  0.301491  0.685084
# 6        6  0.000062  0.999929
# 7        7  0.471654  0.899201
# 8        8 -0.165717  1.046215
# 9        9  0.436089  1.085925
# 10      10 -0.022288  1.013404
# 11      11 -0.633382  1.601868
# 12      12 -0.154963  1.105271
# 13      13  0.069011  0.930008
# 14      14 -0.000404  1.001304
# 15      15  0.022665  0.986814
# 16      16  0.000169  1.000000
# 17      17  0.313655  0.741898
# 18      18  0.270409  0.708321
# 19      19  0.000189  0.999392
# 20      20  0.369418  0.826742
# 21      21  0.309704  0.687531
# 22      22  0.197357  0.956671
# 23      23 -0.515296  1.617382
# 24      24 -0.944959  1.929799
# 25      25 -0.810241  1.727382
# 26      26  0.000000  1.000000
# 27      27  0.000000  0.000000
# 28      28  0.000000  1.000000
# 29      29  0.500000  0.500000
# 30      30  1.000000  1.000000
# 31      31  0.500000  0.500000
# 32      32  0.003506  0.999795
